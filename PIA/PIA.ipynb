# %% [markdown]
# <a href="https://colab.research.google.com/github/dilp90/IA_Veranos2026/blob/main/PIA/PIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Este es mi primer notebook en colab**

# %%
print("¡Hola mundo!")
# Out:
# ¡Hola mundo!
